# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# ## La función plot

# %%
plt.plot([2,6,7,3,8])
plt.show()

# %% [markdown]
# ### La función subplots
# Crea una figura y uno o más conjuntos de ejes (por defecto se crea uno solo)

# %%
fig, ax = plt.subplots()
ax.plot([2,6,7,3,8])
plt.show(np.)

# %% [markdown]
# ### Las funciones figure y axes
# - figure crea de forma explícita una figura
# - axes crea de forma explícita un conjunto de ejes en la última figura que se haya creado o referenciado

# %% [markdown]
# ### Interfaces de programación
# #### Interfaz estilo "MATLAB"

# %%
plt.figure()
plt.subplot(1,2,1)
plt.plot([2,6,7,3,8])
plt.title('Ventas')
plt.xticks(range(0,5),['Ene','Feb','Mar','Abr','May'])
plt.subplot(np.random.randint(1,10,100), bins=9)
plt.title('Almacenes')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 6
#       4 plt.title('Ventas')
#       5 plt.xticks(range(0,5),['Ene','Feb','Mar','Abr','May'])
# ----> 6 plt.subplot(np.random.randint(1,10,100), bins=9)
#       7 plt.title('Almacenes')
#       8 plt.show()
#
# File ~\anaconda3\envs\LabMatematicas\Lib\site-packages\matplotlib\pyplot.py:1440, in subplot(*args, **kwargs)
#    1437 fig = gcf()
#    1439 # First, search for an existing subplot with a matching spec.
# -> 1440 key = SubplotSpec._from_subplot_args(fig, args)
#    1442 for ax in fig.axes:
#    1443     # If we found an Axes at the position, we can re-use it if the user passed no
#    1444     # kwargs or if the axes class and kwargs are identical.
#    1445     if (ax.get_subplotspec() == key
#    1446         and (kwargs == {}
#    1447              or (ax._projection_init
#    1448                  == fig._process_projection_requirements(**kwargs)))):
#
# File ~\anaconda3\envs\LabMatematicas\Lib\site-packages\matplotlib\gridspec.py:574, in SubplotSpec._from_subplot_args(figure, args)
#     572     return arg
#     573 elif not isinstance(arg, Integral):
# --> 574     raise ValueError(
#     575         f"Single argument to subplot must be a three-digit "
#     576         f"integer, not {arg!r}")
#     577 try:
#     578     rows, cols, num = map(int, str(arg))
#
# ValueError: Single argument to subplot must be a three-digit integer, not array([8, 1, 4, 8, 9, 7, 7, 7, 9, 3, 8, 3, 8, 1, 6, 2, 4, 9, 5, 3, 5, 6,
#        4, 2, 4, 9, 3, 8, 5, 1, 5, 6, 3, 9, 9, 8, 6, 2, 9, 3, 6, 8, 1, 2,
#        2, 1, 9, 3, 2, 6, 2, 2, 2, 7, 1, 6, 7, 6, 8, 7, 3, 5, 1, 2, 8, 7,
#        3, 4, 9, 6, 9, 3, 5, 3, 1, 6, 8, 3, 5, 1, 9, 3, 6, 6, 6, 5, 6, 7,
#        7, 9, 5, 9, 5, 2, 8, 4, 9, 8, 9, 4])
